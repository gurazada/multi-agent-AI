# %% [markdown]
# ## 1. Install required libraries

# %%
# !pip install gradio pandas numpy matplotlib pillow scikit-learn joblib langchain langgraph
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.11/dist-packages (5.41.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (1.5.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.27)
# Requirement already satisfied: langgraph in /usr/local/lib/python3.11/dist-packages (0.6.4)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.10.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (1.1.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.116.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio) (0.6.1)
# Requirement already satisfied: gradio-client==1.11.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (1.11.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.33.5 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.34.3)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (3.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gradio) (25.0)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.11.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (6.0.2)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.12.7)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.47.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.16.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (4.14.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio) (0.35.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.11.0->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.11.0->gradio) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.72)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.4.12)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.42)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from langgraph) (2.1.1)
# Requirement already satisfied: langgraph-prebuilt<0.7.0,>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.6.4)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from langgraph) (0.2.0)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from langgraph) (3.5.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (3.18.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.33.5->gradio) (1.1.7)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: ormsgpack>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.10.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %% [markdown]
# ## 2. Synthetic Data Generation - Core method
# > generate_batch_data()

# %%
import pandas as pd
import numpy as np

def generate_batch_data(batch_length=48, seed=None):
    np.random.seed(seed) # Ensures variability between runs
    time_points = np.arange(batch_length + 1)

    # Simulated bioprocess values with realistic time trends
    pH = 7 + 0.02 * np.sin(0.2 * time_points) + np.random.normal(0, 0.05, batch_length + 1)
    temperature = 37 + np.random.normal(0, 0.5, batch_length + 1)
    viability = 95 + 5 * np.exp(-0.1 * (time_points - 30).clip(min=0)) + np.random.normal(0, 1, batch_length + 1)
    viability = np.clip(viability, 70, 100)
    max_vcd = 30
    vcd = max_vcd / (1 + np.exp(-0.3 * (time_points - 24))) + np.random.normal(0, 1, batch_length + 1)
    vcd = np.clip(vcd, 0, None)
    do = 80 - 0.5 * time_points + np.random.normal(0, 2, batch_length + 1)
    do = np.clip(do, 10, 100)
    co2 = 0.05 + 0.02 * time_points + np.random.normal(0, 0.005, batch_length + 1)
    co2 = np.clip(co2, 0, None)
    max_titer = 5
    titer = max_titer / (1 + np.exp(-0.3 * (time_points - 30))) + np.random.normal(0, 0.1, batch_length + 1)
    titer = np.clip(titer, 0, None)
    growth_rate = 0.5 * np.exp(-0.1 * time_points) + 0.05 * np.random.normal(0, 1, batch_length + 1)
    growth_rate = np.clip(growth_rate, 0, None)
    glucose = 5 * np.exp(-0.05 * time_points) + np.random.normal(0, 0.1, batch_length + 1)
    glucose = np.clip(glucose, 0, None)
    lactate = 2 / (1 + np.exp(-0.3 * (time_points - 20))) + np.random.normal(0, 0.1, batch_length + 1)
    lactate = np.clip(lactate, 0, None)
    ammonia = 0.5 * np.log1p(time_points) + np.random.normal(0, 0.05, batch_length + 1)
    ammonia = np.clip(ammonia, 0, None)
    calcium = 1.8 + np.random.normal(0, 0.05, batch_length + 1)
    calcium = np.clip(calcium, 0, None)
    na_k_ratio = 2 + 0.5 * np.sin(0.1 * time_points) + np.random.normal(0, 0.1, batch_length + 1)
    na_k_ratio = np.clip(na_k_ratio, 1, 4)
    agitation = 200 + np.random.normal(0, 5, batch_length + 1)
    cell_bleed = np.where(time_points > 36, 0.5 * (time_points - 36) + np.random.normal(0, 0.1, batch_length + 1), 0)
    cell_bleed = np.clip(cell_bleed, 0, None)
    culture_time = time_points

    batch_data = pd.DataFrame({
        'culture_time_hr': culture_time,
        'pH': pH,
        'temperature_C': temperature,
        'viability_pct': viability,
        'viable_cell_density_million_per_mL': vcd,
        'dissolved_oxygen_pct': do,
        'carbon_dioxide_pct': co2,
        'titer_g_per_L': titer,
        'growth_rate_per_hr': growth_rate,
        'glucose_g_per_L': glucose,
        'lactate_g_per_L': lactate,
        'ammonia_mM': ammonia,
        'calcium_mM': calcium,
        'sodium_potassium_ratio': na_k_ratio,
        'agitation_rpm': agitation,
        'cell_bleed_volume_mL': cell_bleed
    })
    return batch_data

# %% [markdown]
# ### Optional - Visual dashboard to generate batch data

# %%
import matplotlib.pyplot as plt
import gradio as gr
import io
from PIL import Image
import traceback

def run_batch_simulation(batch_length=48):
    try:
        df = generate_batch_data(batch_length)
        csv_path = 'batch_data.csv'
        df.to_csv(csv_path, index=False)

        fig, axs = plt.subplots(3, 1, figsize=(8, 10))
        axs[0].plot(df['culture_time_hr'], df['viability_pct'], label='Viability %')
        axs[0].plot(df['culture_time_hr'], df['viable_cell_density_million_per_mL'], label='Viable Cell Density (M/mL)')
        axs[0].legend()
        axs[0].set_title('Cell Viability & Density Over Time')

        axs[1].plot(df['culture_time_hr'], df['pH'], label='pH', color='green')
        axs[1].plot(df['culture_time_hr'], df['temperature_C'], label='Temperature (C)', color='orange')
        axs[1].legend()
        axs[1].set_title('pH and Temperature Over Time')

        axs[2].plot(df['culture_time_hr'], df['titer_g_per_L'], label='Titer (g/L)', color='red')
        axs[2].plot(df['culture_time_hr'], df['glucose_g_per_L'], label='Glucose (g/L)', color='blue')
        axs[2].legend()
        axs[2].set_title('Titer and Glucose Over Time')

        plt.tight_layout()
        buf = io.BytesIO()
        plt.savefig(buf, format='png')
        buf.seek(0)
        img = Image.open(buf).copy() # copy to detach from buffer
        buf.close()
        plt.close(fig)  # prevent memory leaks

        return csv_path, img
    except Exception as e:
        print("Exception in run_batch_simulation:", e)
        traceback.print_exc()
        return None, None


iface = gr.Interface(
    fn=run_batch_simulation,
    inputs=gr.Slider(24, 72, step=1, label='Batch Length (hours)'),
    outputs=[gr.File(label='Download Batch Data CSV'), gr.Image(type='pil', label='Simulation Plot')],
    title='Synthetic Bioprocess Data Generator',
    description='Generates synthetic bioprocess data for a batch and visualizes key parameters.'
)

iface.launch(share=True, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://066e59a74088c789a4.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://066e59a74088c789a4.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://066e59a74088c789a4.gradio.live

# %% [markdown]
# ## 3. Real-time Bioprocess Simulator Agent

# %%
import numpy as np
import pandas as pd
import time

class RealTimeBioprocessSimulator:
    def __init__(self):
        self.t = 0
        self.last_values = {
            'pH': 7.0,
            'temperature_C': 37.0,
            'viability_pct': 95.0,
            'viable_cell_density_million_per_mL': 0,
            'dissolved_oxygen_pct': 80.0,
            'carbon_dioxide_pct': 0.05,
            'titer_g_per_L': 0.0,
            'growth_rate_per_hr': 0.5,
            'glucose_g_per_L': 5.0,
            'lactate_g_per_L': 0.0,
            'ammonia_mM': 0.0,
            'calcium_mM': 1.8,
            'sodium_potassium_ratio': 2.0,
            'agitation_rpm': 200,
            'cell_bleed_volume_mL': 0.0
        }

    def simulate_one_step(self):
        t = self.t
        # Generate new values using the same trends as before
        self.last_values['pH'] = 7 + 0.02 * np.sin(0.2 * t) + np.random.normal(0, 0.05)
        self.last_values['temperature_C'] += np.random.normal(0, 0.15)
        self.last_values['viability_pct'] = np.clip(95 + 5 * np.exp(-0.1 * max(0, t-30)) + np.random.normal(0, 1), 70, 100)
        self.last_values['viable_cell_density_million_per_mL'] = np.clip(30 / (1 + np.exp(-0.3 * (t-24))) + np.random.normal(0, 1), 0, None)
        self.last_values['dissolved_oxygen_pct'] = np.clip(80 - 0.5 * t + np.random.normal(0, 2), 10, 100)
        self.last_values['carbon_dioxide_pct'] = np.clip(0.05 + 0.02 * t + np.random.normal(0, 0.005), 0, None)
        self.last_values['titer_g_per_L'] = np.clip(5 / (1 + np.exp(-0.3 * (t-30))) + np.random.normal(0, 0.1), 0, None)
        self.last_values['growth_rate_per_hr'] = np.clip(0.5 * np.exp(-0.1 * t) + 0.05 * np.random.normal(0, 1), 0, None)
        self.last_values['glucose_g_per_L'] = np.clip(5 * np.exp(-0.05 * t) + np.random.normal(0, 0.1), 0, None)
        self.last_values['lactate_g_per_L'] = np.clip(2 / (1 + np.exp(-0.3 * (t-20))) + np.random.normal(0, 0.1), 0, None)
        self.last_values['ammonia_mM'] = np.clip(0.5 * np.log1p(t) + np.random.normal(0, 0.05), 0, None)
        self.last_values['calcium_mM'] = np.clip(1.8 + np.random.normal(0, 0.05), 0, None)
        self.last_values['sodium_potassium_ratio'] = np.clip(2 + 0.5 * np.sin(0.1 * t) + np.random.normal(0, 0.1), 1, 4)
        self.last_values['agitation_rpm'] = 200 + np.random.normal(0, 5)
        self.last_values['cell_bleed_volume_mL'] = np.clip(0.5 * (t - 36) + np.random.normal(0, 0.1), 0, None) if t > 36 else 0

        data = {
            'culture_time_hr': t,
            **self.last_values
        }
        self.t += 1
        return pd.DataFrame([data])

# Example usage: stream one row per simulated hour
sim = RealTimeBioprocessSimulator()
for _ in range(48):
    df = sim.simulate_one_step()
    print(df)  # Replace with code to push to downstream agent
    # time.sleep(1)  # Uncomment for real-time pacing, or set to time.sleep(3600) to "run hourly"
# Out:
#    culture_time_hr       pH  temperature_C  viability_pct  \
# 0                0  6.95037      36.912954       99.28847
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            1.017821             79.005881
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.049967       0.007663            0.518374         5.081778
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0              0.0         0.0    1.836919                1.981673
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     203.630648                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0                1  6.986817      36.853612          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                              2.3304             79.755179
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0             0.07358       0.011023            0.548389         4.876353
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0              0.0     0.44744    1.736808                2.085424
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     201.399888                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0                2  6.953589      36.663066      97.642949
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            0.588839             81.495944
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.084243            0.0            0.452853         4.588636
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0              0.0    0.562024    1.773869                2.325669
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     193.923321                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0                3  6.997884      36.855988      99.708329
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            1.719078             81.337992
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.108543            0.0            0.368563         4.348961
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0              0.0    0.702519    1.733581                2.266035
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     196.908683                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0                4  7.039367      36.663507          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            0.583341             82.135907
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.130759       0.053367             0.33697         4.191317
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0              0.0    0.763059    1.852841                2.151479
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     203.736993                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0                5  7.036963      36.629594          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                             0.68999             78.771961
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.141988       0.064314            0.304738         3.715444
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0              0.0    0.910842    1.742745                2.283472
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     207.177019                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0                6  7.079802      36.392239          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                                 0.0             76.193014
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.170211       0.023774            0.271223         3.673901
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.018971    0.986566    1.860338                2.182173
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     198.481098                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0                7  6.964841      36.550733          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            0.214307             76.828364
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.184705            0.0            0.275514         3.508334
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.227631    0.956366     1.83309                2.377537
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     197.600342                     0
#    culture_time_hr       pH  temperature_C  viability_pct  \
# 0                8  7.07659      36.551228      98.613031
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            0.345189             77.160903
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.203231            0.0            0.230447         3.232424
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.029552    1.112811    1.829193                2.296634
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     198.778484                     0
#    culture_time_hr      pH  temperature_C  viability_pct  \
# 0                9  7.1145      36.558386      99.480623
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            1.412625             75.263173
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.223414       0.097287            0.176466         3.137098
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.240139    1.145523    1.782044                2.532512
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     204.714619                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               10  7.072127      36.754134          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            0.105203             73.953299
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0             0.24546       0.035476            0.156012         2.979333
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0              0.0    1.142639    1.785995                2.385444
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     205.291748                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               11  7.023103      36.549881       98.74624
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            0.979845             73.893398
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.274704       0.016869            0.105632         2.978426
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.098224    1.236532    1.824259                2.294035
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     199.394243                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               12  6.987418      36.390467      99.745801
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                             0.37944             73.608887
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.296837            0.0              0.1526         2.678164
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0          0.33958    1.279541    1.807971                2.588811
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     202.143437                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               13  6.978284      36.447158          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            1.177857              74.80103
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.312038       0.178746            0.131198         2.520636
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.024934    1.273614    1.815368                2.475198
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     201.523987                     0
#    culture_time_hr       pH  temperature_C  viability_pct  \
# 0               14  7.09142      36.574411          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            1.613426             70.692609
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.331251            0.0            0.140314         2.437985
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.280402    1.270619    1.790244                2.419871
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     200.487718                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               15  6.948031       36.70149          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            0.881464             72.816058
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0             0.34886       0.029143            0.084057         2.409324
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.567345    1.347388    1.723168                2.599192
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     202.489103                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               16  6.964512      36.455538          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            0.309631             70.798246
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.362666       0.095742            0.183952         2.220068
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.307549    1.329991    1.708782                 2.47769
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     195.299906                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               17  6.952071       36.56235          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            2.512445             69.534907
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.387799            0.0            0.118496         1.948233
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.545755     1.39967    1.761604                2.339215
#
#    agitation_rpm  cell_bleed_volume_mL
# 0      201.36538                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               18  7.016266      36.393736          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            4.099448             68.831009
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.406405        0.04687            0.152775         1.965148
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.971002    1.495042    1.832294                2.408377
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     196.860902                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               19  6.962916      36.468865          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            6.664794             70.658278
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.423925       0.230655            0.083681         1.909425
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.980333    1.570361    1.836982                2.302408
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     202.378542                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               20  6.913317      36.336778      99.737725
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                             6.92369             74.284098
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.449524       0.217375             0.06776          1.77209
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         0.984593    1.542117    1.885838                2.525017
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     198.355413                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               21  6.889987      36.162143          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            9.214121             67.892156
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.477022       0.428282             0.10236         1.837983
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.132414     1.57263    1.714987                2.420578
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     203.919518                     0
#    culture_time_hr       pH  temperature_C  viability_pct  \
# 0               22  7.04476      36.081312          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           13.403851             68.763303
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.485879       0.128514            0.010108         1.871439
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.350254    1.488333    1.869856                2.445487
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     197.471298                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               23  6.988917      36.142794          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           12.959639              70.89231
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0             0.52001        0.69077            0.121588         1.461759
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.328469    1.589451    1.740958                 2.12554
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     201.615921                     0
#    culture_time_hr       pH  temperature_C  viability_pct  \
# 0               24  7.02756      36.148646          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           16.849746             65.613954
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.533507        0.71298            0.054836         1.534794
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.621057     1.56634    1.846174                2.395306
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     205.751836                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               25  7.040256      36.190825      99.963099
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           17.182004             73.561257
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.556665       0.941584            0.002002         1.509685
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.543855    1.606655    1.805823                2.243291
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     198.551822                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               26  6.870007      35.954332      99.748968
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           19.017599               66.3588
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.577426       1.318114            0.048773         1.371192
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.729716    1.596466    1.763213                2.354736
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     196.512451                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               27  7.012704      35.677834      99.284539
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           22.586521             68.878154
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.581022       1.443123            0.003349         1.251467
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.904238     1.64376     1.81412                2.000936
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     193.604675                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               28  6.966809      35.726079          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           25.589939             65.037247
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.615321       1.687646            0.108159         1.070124
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.983212    1.628077    1.794303                2.234673
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     199.573651                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               29  7.009432      35.669468      98.862849
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           26.359395             67.357184
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0             0.62642        2.04515                 0.0         1.246199
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.914263    1.722603    1.827856                2.152259
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     195.083457                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               30  6.966106      35.710692          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           25.449066             65.730149
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.639565       2.556469                 0.0         1.121363
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.921762    1.737539    1.722635                2.151119
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     192.265019                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               31  6.990291      35.579489      98.520442
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           26.903876             66.557476
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0               0.676       2.907417            0.030595         1.039139
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.788421    1.751919    1.848854                 2.05084
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     196.183916                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               32  7.078705      35.453141      99.161722
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           28.575495             64.571412
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.699337       2.969364            0.074393         0.959448
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0          2.03766    1.746786    1.774536                1.930086
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     197.753277                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               33  7.007688      35.446995      99.786309
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            29.41328             61.931862
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.717861       3.598827            0.035447         0.973191
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.985221    1.792687    1.677885                1.907718
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     203.113909                     0
#    culture_time_hr      pH  temperature_C  viability_pct  \
# 0               34  6.9792       35.12068      98.384274
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            26.64073             64.218442
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.734557       3.712609            0.019599         0.925112
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.843201    1.725611    1.841595                1.808824
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     202.135636                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               35  6.989527      35.004414       99.78561
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           28.758074             63.096364
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.749845       3.889026                 0.0         0.767071
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.971335    1.830642    1.857855                1.939174
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     198.404975                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               36  6.982268      35.235957      98.549428
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           27.561493             62.797998
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.770871       4.240275            0.015235          0.84669
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.868935    1.795373    1.830983                1.586025
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     209.057569                     0
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               37  7.016654      35.105042      97.968191
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           29.181124             59.639359
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.786819       4.539686                 0.0         0.900496
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.875348    1.816726    1.819861                1.710302
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     205.301621              0.521294
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               38  7.083603      34.943988      96.899499
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           29.940605             63.513808
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.808425       4.602128                 0.0         0.670444
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0          2.11138    1.903864    1.877098                1.729716
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     195.647222              0.945685
#    culture_time_hr       pH  temperature_C  viability_pct  \
# 0               39  7.00346      35.263371      96.415533
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                             29.3523             59.576484
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.840486       4.615586                 0.0         0.686612
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         2.059699    1.903387     1.78855                1.799852
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     204.022336              1.600421
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               40  7.010473      35.366908      97.785717
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                            29.59147             61.695883
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.862498       4.647998            0.069355         0.614955
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.836264    1.911425    1.789245                1.783126
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     203.711665              2.128869
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               41  6.958899      35.645447        96.9217
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           30.853847             57.179848
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.865989       4.909456            0.030237         0.683551
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.955679    1.833482    1.852472                1.504371
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     202.960355              2.441796
#    culture_time_hr       pH  temperature_C  viability_pct  \
# 0               42  6.96862      35.632555       97.00571
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           29.215746             60.994998
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0             0.88354       4.934213            0.045312         0.497817
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0          1.99606    1.874295    1.738054                1.545617
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     207.561549              3.010844
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               43  7.077567      35.559059      97.829795
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           28.261689              58.41342
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.919204       5.106837            0.105733         0.552881
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.951197    1.910379    1.774839                1.671901
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     204.802835              3.370411
#    culture_time_hr       pH  temperature_C  viability_pct  \
# 0               44  6.97104      35.576313      94.121215
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           30.695816             56.965305
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0             0.93344       4.832236                 0.0         0.602392
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.955269    1.964587    1.791808                1.489501
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     200.880843              4.076851
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               45  7.077319      35.562613      96.012952
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           29.849228             58.822163
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.951921       5.140061            0.018351         0.621722
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         2.090191    1.936793    1.819631                1.407482
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     194.162181               4.41453
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               46  6.973868      35.472435       95.93602
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           29.036578             60.153336
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.969621       5.069039            0.063212         0.409423
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.932856    1.944192    1.820178                1.645098
#
#    agitation_rpm  cell_bleed_volume_mL
# 0      200.01703              5.069533
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0               47  7.083027      35.514846      96.951579
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                           31.289608             55.752019
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.989029       4.938071                 0.0         0.694734
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0         1.942355    1.936318    1.847906                 1.62901
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     195.051411               5.40654

# %% [markdown]
# ## 4. Create training data from multiple batches

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import joblib  # For saving/loading models

# Generating Union Dataset (Training)
def create_training_data(num_batches=20, batch_length=240):
    batches = [generate_batch_data(batch_length, seed=i) for i in range(num_batches)]
    for idx, batch in enumerate(batches):
        batch['batch_id'] = idx
    df = pd.concat(batches, ignore_index=True)

    ## The multi-batch sample training dataset is merged into one dataframe - df
    ## Now creating the sample Y label - Viability collapse

    # Label collapse per batch: 1 if any sample in batch <75% viability
    # collapse_labels = []
    # for i in range(num_batches):
    #     batch = df[df['batch_id'] == i]
    #     collapse = int((batch['viability_pct'] < 75).any())
    #     collapse_labels.extend([collapse]*len(batch))
    # df['viability_collapse'] = collapse_labels

    # Label collapse per sample: 1 if viability < cutoff in next 24 hrs
    df['viability_collapse'] = 0
    window = 24  # 24 hours
    viability_cutoff = 93 # viability%
    for idx in range(len(df) - 1):
        current_time = df.loc[idx, 'culture_time_hr']
        current_batch = df.loc[idx, 'batch_id']
        # Find all future points within the next 24 hours
        mask = (df['batch_id'] == current_batch) & (df['culture_time_hr'] > current_time) & (df['culture_time_hr'] <= current_time + window)
        # If any future viability drops below cutoff, set target to 1
        if (df.loc[mask, 'viability_pct'] < viability_cutoff).any():
            df.loc[idx, 'viability_collapse'] = 1

    return df

# Example training data
train_df = create_training_data()
train_df
# Out:
#       culture_time_hr        pH  temperature_C  viability_pct  \
# 0                   0  7.088203      36.801364      99.091237
# 1                   1  7.023981      36.933560      99.575682
# 2                   2  7.056725      36.851105     100.000000
# 3                   3  7.123338      36.845494      97.344381
# 4                   4  7.107725      36.161998     100.000000
# ...               ...       ...            ...            ...
# 4815              236  6.991636      37.516879      93.963209
# 4816              237  6.911179      36.473015      95.440799
# 4817              238  6.974501      36.799957      94.350828
# 4818              239  7.025948      37.399471      95.171480
# 4819              240  6.968702      36.287252      93.851652
#
#       viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                               0.000000             79.007795
# 1                               0.000000             79.350390
# 2                               0.000000             79.024464
# 3                               0.000000             81.638519
# 4                               1.317498             79.380858
# ...                                  ...                   ...
# 4815                           31.547486             10.000000
# 4816                           29.983627             10.000000
# 4817                           31.272352             10.000000
# 4818                           29.544898             10.000000
# 4819                           30.071084             10.000000
#
#       carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0               0.043928       0.000000            0.480460         5.105418
# 1               0.074355       0.088927            0.512911         4.851230
# 2               0.085610       0.181937            0.339060         4.580117
# 3               0.116481       0.045181            0.290172         4.197170
# 4               0.133082       0.021321            0.408096         4.050544
# ...                  ...            ...                 ...              ...
# 4815            4.766296       5.034095            0.012290         0.040307
# 4816            4.790813       4.897863            0.000000         0.000000
# 4817            4.805787       4.905842            0.049505         0.125054
# 4818            4.833524       5.047835            0.125461         0.278208
# 4819            4.841458       5.022099            0.050045         0.000000
#
#       lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0            0.092496    0.000000    1.818644                2.099032
# 1            0.031897    0.337951    1.844315                2.212560
# 2            0.237553    0.580983    1.797237                2.228599
# 3            0.049712    0.662706    1.724984                2.299248
# 4            0.000000    0.793413    1.759075                2.355142
# ...               ...         ...         ...                     ...
# 4815         1.942195    2.765664    1.770852                1.563270
# 4816         2.006316    2.709609    1.860074                1.601166
# 4817         2.084296    2.658822    1.816758                1.449486
# 4818         2.039719    2.644848    1.774073                1.651496
# 4819         1.874732    2.685162    1.801274                1.745674
#
#       agitation_rpm  cell_bleed_volume_mL  batch_id  viability_collapse
# 0        196.936807              0.000000         0                   0
# 1        198.093551              0.000000         0                   0
# 2        193.755255              0.000000         0                   0
# 3        198.348811              0.000000         0                   0
# 4        195.825964              0.000000         0                   0
# ...             ...                   ...       ...                 ...
# 4815     203.967634            100.134227        19                   0
# 4816     198.998647            100.362311        19                   0
# 4817     200.645573            101.123049        19                   0
# 4818     205.913951            101.611121        19                   0
# 4819     193.514220            101.873666        19                   0
#
# [4820 rows x 18 columns]

# %%
# @title viability_pct

from matplotlib import pyplot as plt
train_df['viability_pct'].plot(kind='line', figsize=(8, 4), title='viability_pct')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title viability_collapse

from matplotlib import pyplot as plt
train_df['viability_collapse'].plot(kind='line', figsize=(8, 4), title='viability_collapse')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ## 5. Upstream Viability Agent

# %%
class UpstreamViabilityAgent:
    def __init__(self, model_path="viability_collapse_rf.pkl"):
        self.model_path = model_path
        self.model = None

    def train(self, train_df):
        feat_cols = [
            'culture_time_hr', 'pH', 'temperature_C', 'viability_pct',
            'viable_cell_density_million_per_mL', 'dissolved_oxygen_pct',
            'carbon_dioxide_pct', 'titer_g_per_L', 'growth_rate_per_hr',
            'glucose_g_per_L', 'lactate_g_per_L', 'ammonia_mM', 'calcium_mM',
            'sodium_potassium_ratio', 'agitation_rpm', 'cell_bleed_volume_mL'
        ]
        X = train_df[feat_cols]
        y = train_df['viability_collapse']
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)
        self.model = RandomForestClassifier()
        self.model.fit(X_train, y_train)
        print("Validation accuracy:", self.model.score(X_test, y_test))
        joblib.dump(self.model, self.model_path)

    def load(self):
        self.model = joblib.load(self.model_path)

    def predict(self, sample_row):
        # sample_row: sample dataframe, e.g. one hourly sample
        feat_cols = [
            'culture_time_hr', 'pH', 'temperature_C', 'viability_pct',
            'viable_cell_density_million_per_mL', 'dissolved_oxygen_pct',
            'carbon_dioxide_pct', 'titer_g_per_L', 'growth_rate_per_hr',
            'glucose_g_per_L', 'lactate_g_per_L', 'ammonia_mM', 'calcium_mM',
            'sodium_potassium_ratio', 'agitation_rpm', 'cell_bleed_volume_mL'
        ]
        features = sample_row[feat_cols] #.values.reshape(1, -1)
        pred = self.model.predict(features)
        return int(pred[0])  # 1=collapse, 0=no collapse

# %% [markdown]
# ## 6. Real-time Prediction Pipeline

# %% [markdown]
# ### step-1: Starting up the agent, creating predictive model on training data and saving the model

# %%
# Train and save the model
agent = UpstreamViabilityAgent()
agent.train(train_df)  # Only needs to be run once for initial training
# Out:
# Validation accuracy: 0.6773858921161826

# %% [markdown]
# ### step-2: Loading the saved model and initiating the real-time bioprocess simulator

# %%
# For each new hourly sample from the simulator:
agent.load()  # Loads the saved model
sim = RealTimeBioprocessSimulator()

# %% [markdown]
# ### step-3: pulling next datapoint from real-time simulator and the viability agent outputting the prediction

# %%
sample_row = sim.simulate_one_step() #.iloc[0]
print(sample_row)
collapse_pred = agent.predict(sample_row)
print(f"Viability collapse predicted: {collapse_pred}")
# Out:
#    culture_time_hr        pH  temperature_C  viability_pct  \
# 0                0  6.978875      37.045961          100.0
#
#    viable_cell_density_million_per_mL  dissolved_oxygen_pct  \
# 0                                 0.0             81.228736
#
#    carbon_dioxide_pct  titer_g_per_L  growth_rate_per_hr  glucose_g_per_L  \
# 0            0.041171       0.061852            0.572517         5.076342
#
#    lactate_g_per_L  ammonia_mM  calcium_mM  sodium_potassium_ratio  \
# 0              0.0         0.0     1.87534                2.105521
#
#    agitation_rpm  cell_bleed_volume_mL
# 0     206.242642                     0
# Viability collapse predicted: 0

# %% [markdown]
# ## LangGraph Multi-Agent Workflow

# %%
from google.colab import userdata
import os

# Access the API key from Colab secrets
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %% [markdown]
# ### Step-1: Define LangGraph State and Nodes
# LangGraph nodes are Python functions that take and return a State dict. Each holds agent instances and evolving data.

# %%
from typing import TypedDict
from langgraph.graph import StateGraph, START, END
import pandas as pd # Ensure pandas is imported

class State(TypedDict):
    sim: RealTimeBioprocessSimulator
    agent: UpstreamViabilityAgent
    sample: pd.DataFrame
    prediction: int
    history: list # Added history to the State definition

# Simulator node
def simulator_node(state: State) -> State:
    sim = state.get('sim')
    if sim is None:
        sim = RealTimeBioprocessSimulator()
        state['sim'] = sim
    sample = sim.simulate_one_step()
    state['sample'] = sample
    # Append the sample data (converted to dict) to the history list in state
    # Initialize history if it doesn't exist (though run_workflow should handle this)
    if 'history' not in state or not isinstance(state['history'], list):
         state['history'] = []

    # Add the sample and prediction to the history for plotting/logging
    # We need the prediction to be available in the history for the log_str
    # Let's add the sample data and potentially the prediction (if available from a previous step)
    # A better approach might be to add prediction in the predictor_node and then update history
    # Let's simplify for now and just add the sample dict. We'll handle prediction logging differently.
    sample_dict = sample.iloc[0].to_dict()
    state['history'].append(sample_dict) # Append the sample data to history

    return state

# Predictor node
def predictor_node(state: State) -> State:
    agent = state.get('agent')
    if agent is None: # Initialize agent if not in state
        agent = UpstreamViabilityAgent()
        # Check if the model file exists before loading
        try:
            agent.load() # Load the saved model
            state['agent'] = agent
        except FileNotFoundError:
            print("Model file not found. Please train the agent first.")
            # Handle the error - perhaps set prediction to None or a specific error value
            state['prediction'] = -1 # Indicate error
            return state # Exit early if model not found

    sample = state.get('sample')
    if sample is None:
        print("No sample available for prediction.")
        state['prediction'] = -1 # Indicate no sample
        return state

    try:
        pred = agent.predict(sample)
        state['prediction'] = pred
         # Update the last entry in history with the prediction
        if state.get('history'):
            state['history'][-1]['viability_collapse_pred'] = pred
    except Exception as e:
        print(f"Error during prediction: {e}")
        state['prediction'] = -1 # Indicate error
        if state.get('history'):
             state['history'][-1]['viability_collapse_pred'] = -1 # Indicate error in history entry

    return state

# %% [markdown]
# ### Step-2: Build and compile the LangGraph

# %%
graph = StateGraph(State)

graph.add_node('simulator', simulator_node)
graph.add_node('predictor', predictor_node)

graph.add_edge(START, 'simulator')
graph.add_edge('simulator', 'predictor')
graph.add_edge('predictor', END)

chain = graph.compile()

# %%
import matplotlib.pyplot as plt
import networkx as nx

# manually build the structure
G = nx.DiGraph()
G.add_edges_from([
    ('START', 'simulator'),
    ('simulator', 'predictor'),
    ('predictor', 'END'),
])
nx.draw(G, with_labels=True, arrows=True)
plt.show()

# %% [markdown]
# ### Step-3: Running the Multi-Agent Graph
# Trigger the graph in a loop to simulate “real-time” streaming of samples

# %%
state = {}
num_hours = 100
results = []
for i in range(num_hours):
    state = chain.invoke(state)
    sample = state['sample']
    prediction = state['prediction']
    results.append({
        'hour': i,
        'viability_pct': sample['viability_pct'].iloc[0],
        'viability_collapse_pred': prediction
    })

import pprint
pprint.pprint(results)
# Out:
# [{'hour': 0,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.63092576499336)},
#  {'hour': 1, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 2,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.0818419663562)},
#  {'hour': 3, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 4,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.74203015557902)},
#  {'hour': 5,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.70286611519411)},
#  {'hour': 6, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 7,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.9106601292012)},
#  {'hour': 8, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 9,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.84888044624937)},
#  {'hour': 10,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.05349843232304)},
#  {'hour': 11, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 12, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 13,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(98.1547532698328)},
#  {'hour': 14,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.38922751594842)},
#  {'hour': 15,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.33103851519502)},
#  {'hour': 16,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(98.75330817120378)},
#  {'hour': 17, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 18,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.53131436329853)},
#  {'hour': 19,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.22173935318555)},
#  {'hour': 20,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(97.86583436788017)},
#  {'hour': 21,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.58493130107202)},
#  {'hour': 22,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(98.26392564159484)},
#  {'hour': 23, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 24, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 25, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 26, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 27,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(98.69702798813344)},
#  {'hour': 28,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.86038459826862)},
#  {'hour': 29,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(98.30201466522892)},
#  {'hour': 30, 'viability_collapse_pred': 0, 'viability_pct': np.float64(100.0)},
#  {'hour': 31,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(99.50526286463871)},
#  {'hour': 32,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(98.45329503270848)},
#  {'hour': 33,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(98.3409311636015)},
#  {'hour': 34,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(98.18625842190339)},
#  {'hour': 35,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.12724861699687)},
#  {'hour': 36,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(98.29652292536464)},
#  {'hour': 37,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.98513918275383)},
#  {'hour': 38,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(97.79663334799697)},
#  {'hour': 39,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(97.08937539113992)},
#  {'hour': 40,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.81092486178682)},
#  {'hour': 41,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.16110021032065)},
#  {'hour': 42,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.69034324861839)},
#  {'hour': 43,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.72639049863834)},
#  {'hour': 44,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.93347077021166)},
#  {'hour': 45,
#   'viability_collapse_pred': 1,
#   'viability_pct': np.float64(98.0931007269318)},
#  {'hour': 46,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.7640338815831)},
#  {'hour': 47,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.04049362115668)},
#  {'hour': 48,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.38801322189414)},
#  {'hour': 49,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.1938708988561)},
#  {'hour': 50,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.2498763116414)},
#  {'hour': 51,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.72612276084504)},
#  {'hour': 52,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.88902388802376)},
#  {'hour': 53,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.33553767728817)},
#  {'hour': 54,
#   'viability_collapse_pred': 1,
#   'viability_pct': np.float64(96.1624479271483)},
#  {'hour': 55,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.0188545155451)},
#  {'hour': 56,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(97.56810734119667)},
#  {'hour': 57,
#   'viability_collapse_pred': 1,
#   'viability_pct': np.float64(93.78178133532772)},
#  {'hour': 58,
#   'viability_collapse_pred': 1,
#   'viability_pct': np.float64(94.13446072240966)},
#  {'hour': 59,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.4260801316079)},
#  {'hour': 60,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(93.92831798165571)},
#  {'hour': 61,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(93.82205147338063)},
#  {'hour': 62,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(93.84549273716681)},
#  {'hour': 63,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.24485420802692)},
#  {'hour': 64,
#   'viability_collapse_pred': 1,
#   'viability_pct': np.float64(96.37807222098516)},
#  {'hour': 65,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.94458226956404)},
#  {'hour': 66,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.72285044661668)},
#  {'hour': 67,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.92448533588038)},
#  {'hour': 68,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.41228979808412)},
#  {'hour': 69,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.21009119089321)},
#  {'hour': 70,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.0313443415536)},
#  {'hour': 71,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.41235451202705)},
#  {'hour': 72,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.98847361844199)},
#  {'hour': 73,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.17780992336873)},
#  {'hour': 74,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.25056926269185)},
#  {'hour': 75,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.27656491533753)},
#  {'hour': 76,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.50630577855623)},
#  {'hour': 77,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.96852568286891)},
#  {'hour': 78,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(93.77410892097723)},
#  {'hour': 79,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.62578973120642)},
#  {'hour': 80,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.29736813223003)},
#  {'hour': 81,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.58792058658194)},
#  {'hour': 82,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.09861212166076)},
#  {'hour': 83,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.2597171377906)},
#  {'hour': 84,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(97.06277453627011)},
#  {'hour': 85,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.8117648563656)},
#  {'hour': 86,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(96.09972945849678)},
#  {'hour': 87,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.92976634015781)},
#  {'hour': 88,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.29108009275996)},
#  {'hour': 89,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(93.37054531483972)},
#  {'hour': 90,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.5553107818623)},
#  {'hour': 91,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.28255703688401)},
#  {'hour': 92,
#   'viability_collapse_pred': 1,
#   'viability_pct': np.float64(94.76820841570971)},
#  {'hour': 93,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(94.38271471536697)},
#  {'hour': 94,
#   'viability_collapse_pred': 1,
#   'viability_pct': np.float64(95.96764479023862)},
#  {'hour': 95,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.57125611159992)},
#  {'hour': 96,
#   'viability_collapse_pred': 0,
#   'viability_pct': np.float64(95.97003007475735)},
#  {'hour': 97,
#   'viability_collapse_pred': 1,
#   'viability_pct': np.float64(92.54080733172773)},
#  {'hour': 98,
#   'viability_collapse_pred': 1,
#   'viability_pct': np.float64(93.36804306990382)},
#  {'hour': 99,
#   'viability_collapse_pred': 1,
#   'viability_pct': np.float64(97.99869427665031)}]

# %% [markdown]
# ### Step-4: Build a Gradio Interface with Live Updates

# %%
import gradio as gr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw

def create_status_image(collapse_pred):
    # Create a simple 100x100 PNG with color based on prediction
    img = Image.new('RGB', (100, 100), color='white')
    draw = ImageDraw.Draw(img)
    if collapse_pred == 1:
        # Red circle = collapse
        draw.ellipse((10, 10, 90, 90), fill='red')
    else:
        # Green circle = no collapse
        draw.ellipse((10, 10, 90, 90), fill='green')
    return img

def run_workflow(n_steps, state=None):
    if state is None or not state:
        # Reinitialize state for new session, including history
        state = {'sim': None, 'agent': None, 'sample': None, 'prediction': None, 'history': []}
    # If upgrading legacy state, ensure 'history' key exists (for robustness)
    if 'history' not in state:
        state['history'] = []

    metrics = [] # This list seems intended for single step metrics, but is not used later. Let's keep it for now but note its potential redundancy.
    for _ in range(n_steps):
        state = chain.invoke(state)
        # The simulator_node is now responsible for updating state['history']
        # We still collect sample and prediction for the current step display
        sample = state.get('sample')
        prediction = state.get('prediction')
        if sample is not None:
             # The simulator_node already added the full sample to history
             # We don't need to append the dictionary here again if history is updated in simulator_node
             pass # Let simulator_node manage history

    print(f"Current state keys: {list(state.keys())}")
    # Use the history from the state which is updated by simulator_node
    df = pd.DataFrame(state.get('history', []))

    fig, ax = plt.subplots()
    if not df.empty and 'viability_pct' in df.columns: # Check for column existence
        df['viability_pct'].plot(ax=ax, label="Viability %")
        ax.set_xlabel("Hour")
        ax.set_ylabel("Viability (%)")
        ax.legend()
    plt.close(fig)
    # Create a simple log string from the latest sample in history
    log_str = "No data yet."
    status_img = Image.new('RGB', (100, 100), color='white')  # default blank image
    if not df.empty:
        latest_row = df.iloc[-1]
        latest_viability = latest_row.get('viability_pct', 'N/A')
        latest_prediction = latest_row.get('viability_collapse_pred', 'N/A') # Assuming prediction is added to history
        # We can't reliably get the actual collapse status here unless it's in the data
        # Let's log the predicted collapse status instead if available
        log_str = f"Step {len(df) - 1}: Viability = {latest_viability:.2f} | Collapse pred = {latest_prediction}"
        status_img = create_status_image(latest_prediction)

    # Pass the updated state back to Gradio
    return fig, df.tail(10), log_str, status_img, state # Add status_image to return values

with gr.Blocks() as demo:
    gr.Markdown("# Bioprocess Digital Twin — Live Multi-Agent Workflow Demo")
    with gr.Row():
        steps_slider = gr.Slider(1, 24, value=1, step=1, label="Advance simulation by N hours")
        run_btn = gr.Button("Run")
    with gr.Row():
        plot_box = gr.Plot(label="Viability (%) Over Time")
        table_box = gr.Dataframe(label="Latest Samples")
    with gr.Row():
        log_box = gr.Textbox(label="Agent Log", lines=2)
        status_image = gr.Image(label="Latest Prediction Outcome", type="pil", interactive=False) # Removed shape argument
    state_var = gr.State({}) # Gradio State component to maintain state

    run_btn.click(
        fn=run_workflow,
        inputs=[steps_slider, state_var],
        outputs=[plot_box, table_box, log_box, status_image, state_var] # Add status_image to outputs
    )

if __name__ == "__main__":
    demo.launch(share=True, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://0b04957a05beb1ac9d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0b04957a05beb1ac9d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Current state keys: ['sim', 'agent', 'sample', 'prediction', 'history']
# Current state keys: ['sim', 'agent', 'sample', 'prediction', 'history']
# Current state keys: ['sim', 'agent', 'sample', 'prediction', 'history']
# Current state keys: ['sim', 'agent', 'sample', 'prediction', 'history']
# Current state keys: ['sim', 'agent', 'sample', 'prediction', 'history']
# Current state keys: ['sim', 'agent', 'sample', 'prediction', 'history']
# Current state keys: ['sim', 'agent', 'sample', 'prediction', 'history']
# Current state keys: ['sim', 'agent', 'sample', 'prediction', 'history']
